# %% [markdown]
# <a href="https://colab.research.google.com/github/maskot1977/Computer_and_Exercises_2021/blob/G3pMu6Ar/%E8%AA%B2%E9%A1%8C%EF%BC%92%EF%BC%91.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import urllib.request

url = 'https://raw.githubusercontent.com/maskot1977/ipython_notebook/master/toydata/iris.txt'

urllib.request.urlretrieve(url, 'iris.txt')
# Out:
# ('iris.txt', <http.client.HTTPMessage at 0x7fe64160ec50>)

# %%
col1 = []
col2 = []
col3 = []
for i, line in enumerate(open('iris.txt')):
    if i == 0:
        continue
    c = line.split("\t")
    col1.append(c[0])
    col2.append(float(c[1]))
    col3.append(float(c[2]))

# %%
import matplotlib.pyplot as plt

plt.plot(col2)
plt.plot(col3)
plt.grid() 
plt.show()
